# %%
print("Day2 of AI and ML Course Work")
# Out:
# Day2 of AI and ML Course Work

# %%
a = 5
print("The data type of c is:", type(a)) #integer

b = 8.7
print("The data type of c is:", type(b)) #float

c = a + b
print("The sum of a and b is:", c) #sum of integer and float is float
print("The data type of c is:", type(c)) #float

a = "blah"
print("The data type of a is:", type(a)) #string

a = False
print("The data type of a is:", type(a)) #boolean

#type casting
a = 5
b = 2.3 
c = str(a) + str(b)
print("The concatenated string is:", c) #string concatenation
print("The data type of c is:", type(c)) #string
# Out:
# The sum of a and b is: 13.7
# The data type of c is: <class 'float'>
# The data type of a is: <class 'float'>
# The data type of a is: <class 'str'>
# The data type of a is: <class 'bool'>
# The concatenated string is: 52.3
# The data type of c is: <class 'str'>
